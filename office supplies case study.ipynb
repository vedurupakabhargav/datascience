# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('office supplies.xlsx',sheet_name='Data')
df
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1        IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2        IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                         ...        ...        ...             ...
# 51285   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Postal Code', 'City', 'State', 'Country',
#        'Region', 'Market', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df['Product ID'].nunique()
# Out:
# 3788

# %%
df.shape
# Out:
# (51290, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        51290 non-null  object
#  1   Order Date      51290 non-null  datetime64[ns]
#  2   Ship Date       51290 non-null  datetime64[ns]
#  3   Ship Mode       51290 non-null  object
#  4   Customer ID     51290 non-null  object
#  5   Customer Name   51290 non-null  object
#  6   Segment         51290 non-null  object
#  7   Postal Code     9994 non-null   float64
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Region          51290 non-null  object
#  12  Market          51290 non-null  object
#  13  Product ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub-Category    51290 non-null  object
# ...

# %%
df.isnull()
# Out:
#        Order ID  Order Date  Ship Date  Ship Mode  Customer ID  Customer Name  \
# 0         False       False      False      False        False          False
# 1         False       False      False      False        False          False
# 2         False       False      False      False        False          False
# 3         False       False      False      False        False          False
# 4         False       False      False      False        False          False
# ...         ...         ...        ...        ...          ...            ...
# 51285     False       False      False      False        False          False
# 51286     False       False      False      False        False          False
# 51287     False       False      False      False        False          False
# 51288     False       False      False      False        False          False
# 51289     False       False      False      False        False          False
#
# ...

# %% [markdown]
# # Missing values

# %%
df.isnull().sum()
# Out:
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# Postal Code       41296
# City                  0
# State                 0
# Country               0
# Region                0
# Market                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.shape
# Out:
# (51290, 23)

# %% [markdown]
# # Missing Values Percentile

# %%
(df['Postal Code'].isnull().sum()/df.shape[0])
# Out:
# 0.8051472021836615

# %% [markdown]
# # Outliers

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x='Sales');

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x='Quantity');

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x='Discount');

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x='Profit');

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x='Shipping Cost');

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df,x='Postal Code');

# %% [markdown]
# # cleaning

# %%
df['Postal Code'].fillna(df['Postal Code'].mean())
# Out:
# 0        73120.000000
# 1        55190.379428
# 2        55190.379428
# 3        55190.379428
# 4        55190.379428
#              ...
# 51285    55190.379428
# 51286    37421.000000
# 51287    94109.000000
# 51288    55190.379428
# 51289    55190.379428
# Name: Postal Code, Length: 51290, dtype: float64

# %%
df['postal_code']=df['Postal Code'].fillna(df['Postal Code'].mean())

# %%
df['postal_code']
# Out:
# 0        73120.000000
# 1        55190.379428
# 2        55190.379428
# 3        55190.379428
# 4        55190.379428
#              ...
# 51285    55190.379428
# 51286    37421.000000
# 51287    94109.000000
# 51288    55190.379428
# 51289    55190.379428
# Name: postal_code, Length: 51290, dtype: float64

# %% [markdown]
# # Duplicate

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### EDD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        51290 non-null  object
#  1   Order Date      51290 non-null  datetime64[ns]
#  2   Ship Date       51290 non-null  datetime64[ns]
#  3   Ship Mode       51290 non-null  object
#  4   Customer ID     51290 non-null  object
#  5   Customer Name   51290 non-null  object
#  6   Segment         51290 non-null  object
#  7   Postal Code     9994 non-null   float64
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Region          51290 non-null  object
#  12  Market          51290 non-null  object
#  13  Product ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub-Category    51290 non-null  object
# ...

# %%
df['Order ID'].nunique()
# Out:
# 25728

# %%
df['Order ID'].unique()
# Out:
# array(['CA-2014-AB10015140-41954', 'IN-2014-JR162107-41675',
#        'IN-2014-CR127307-41929', ..., 'IN-2015-KH1633058-42154',
#        'US-2014-ZD21925140-41765', 'MX-2013-MC1810093-41416'],
#       dtype=object)

# %%
df['Order ID'].nunique()/df.shape[0]
# Out:
# 0.5016182491713784

# %%
df['Order Date'].nunique()
# Out:
# 1430

# %%
df['Order Date'].unique()
# Out:
# array(['2014-11-11T00:00:00.000000000', '2014-02-05T00:00:00.000000000',
#        '2014-10-17T00:00:00.000000000', ...,
#        '2012-02-13T00:00:00.000000000', '2013-05-20T00:00:00.000000000',
#        '2012-02-06T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['Order Date'].nunique()/df.shape[0]
# Out:
# 0.027880678494833302

# %%
df['Ship Date'].nunique()
# Out:
# 1464

# %%
df['Ship Date'].unique()
# Out:
# array(['2014-11-13T00:00:00.000000000', '2014-02-07T00:00:00.000000000',
#        '2014-10-18T00:00:00.000000000', ...,
#        '2013-04-08T00:00:00.000000000', '2013-02-26T00:00:00.000000000',
#        '2012-05-15T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df['Ship Date'].nunique()/df.shape[0]
# Out:
# 0.028543575745759407

# %%
df['Ship Mode'].nunique()
# Out:
# 4

# %%
df['Ship Mode'].unique()
# Out:
# array(['First Class', 'Second Class', 'Same Day', 'Standard Class'],
#       dtype=object)

# %%
df['Ship Mode'].nunique()/df.shape[0]
# Out:
# 7.798791187365959e-05

# %%
df['Customer ID'].nunique()
# Out:
# 17415

# %%
df['Customer ID'].unique()
# Out:
# array(['AB-100151402', 'JR-162107', 'CR-127307', ..., 'ZD-219251402',
#        'AS-285147', 'MC-1810093'], dtype=object)

# %%
df['Customer ID'].nunique()/df.shape[0]
# Out:
# 0.3395398713199454

# %%
df['Customer Name'].nunique()
# Out:
# 796

# %%
df['Customer Name'].unique()
# Out:
# array(['Aaron Bergman', 'Justin Ritter', 'Craig Reiter',
#        'Katherine Murray', 'Rick Hansen', 'Jim Mitchum', 'Toby Swindell',
#        'Mick Brown', 'Anthony Jacobs', 'Magdelene Morse',
#        'Vicky Freymann', 'Peter Fuller', 'Ben Peterman', 'Patrick Jones',
#        'Jim Sink', 'Ritsa Hightower', 'Ann Blume', 'Jason Klamczynski',
#        'Laurel Beltran', 'Naresj Patel', 'Valerie Dominguez',
#        'Phillip Breyer', 'Eugene Barchas', 'Aaron Hawkins',
#        'Benjamin Patterson', 'Rick Reed', 'Bill Shonely', 'Dave Poirier',
#        "Patrick O'Donnell", 'Dan Lawera', 'Joy Bell-', 'Barry Franz',
#        'Vivek Grady', 'Greg Tran', 'Zuschuss Carroll', 'Ellis Ballard',
#        'Arthur Prichep', 'Scott Williamson', 'John Huston',
#        'Trudy Glocke', 'Deirdre Greer', 'Sheri Gordon', 'Guy Phonely',
#        'Mitch Webber', 'Chuck Sachs', 'Michael Stewart',
#        'Kimberly Carter', 'Denny Blanton', 'Aaron Smayling', 'Dave Kipp',
# ...

# %%
df['Customer Name'].nunique()/df.shape[0]
# Out:
# 0.015519594462858256

# %%
df['Segment'].nunique()
# Out:
# 3

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].nunique()/df.shape[0]
# Out:
# 5.8490933905244686e-05

# %%
df['Postal Code'].nunique()
# Out:
# 631

# %%
df['Postal Code'].unique()
# Out:
# array([73120.,    nan, 98103., 76017., 12180., 94122., 90004., 10035.,
#        39503., 94109., 19134., 28540., 78745., 94110., 97756., 91104.,
#        22204., 98105., 10009., 22980., 46142.,  3301., 98198., 19143.,
#         2920., 10011., 90036., 89015., 19013., 37918., 30318., 92646.,
#        43229., 65807., 22901., 92037., 75061., 60653., 48205., 77581.,
#        42420., 46203., 97206., 85023., 77041., 61701., 97301., 85705.,
#        77036., 40214., 60505., 75217., 98002., 10701., 11561., 75007.,
#        75220., 74133., 90045., 37087., 43615., 90712., 62521., 80027.,
#        98006., 59405.,  6824., 19120., 33319., 18018., 60623., 10024.,
#        92804., 94513., 37211., 36116., 84604., 80501., 33614., 90049.,
#        19140., 22153., 44105., 90278., 88220., 75023., 44052., 39212.,
#        90008., 68104.,  1841., 84084., 46060., 60067., 75081.,  2038.,
#        89115., 78664., 55407., 85204., 77095., 95207., 28205., 77070.,
# ...

# %%
df['Postal Code'].nunique()/df.shape[0]
# Out:
# 0.0123025930980698

# %%
df['City'].nunique()
# Out:
# 3650

# %%
df['City'].unique()
# Out:
# array(['Oklahoma City', 'Wollongong', 'Brisbane', ..., 'San Mateo',
#        'Portage', 'Victoria Falls'], dtype=object)

# %%
df['City'].nunique()/df.shape[0]
# Out:
# 0.07116396958471437

# %%
df['State'].nunique()
# Out:
# 1102

# %%
df['State'].unique()
# Out:
# array(['Oklahoma', 'New South Wales', 'Queensland', ..., 'Bitola',
#        'Edirne', 'Matabeleland North'], dtype=object)

# %%
df['State'].nunique()/df.shape[0]
# Out:
# 0.021485669721193215

# %%
df['Country'].nunique()
# Out:
# 165

# %%
df['Country'].unique()
# Out:
# array(['United States', 'Australia', 'Germany', 'Senegal', 'New Zealand',
#        'Afghanistan', 'Saudi Arabia', 'Brazil', 'China', 'France',
#        'Italy', 'Tanzania', 'Poland', 'United Kingdom', 'Mexico',
#        'El Salvador', 'Taiwan', 'India', 'Dominican Republic',
#        'Democratic Republic of the Congo', 'Indonesia', 'Uruguay', 'Iran',
#        'Mozambique', 'Bangladesh', 'Spain', 'Ukraine', 'Nicaragua',
#        'Morocco', 'Philippines', 'Austria', 'Colombia', 'Netherlands',
#        'Malaysia', 'Ecuador', 'Thailand', 'Somalia', 'Guatemala',
#        'Belarus', 'Cambodia', 'South Africa', 'Canada', 'Japan', 'Russia',
#        'Egypt', 'Azerbaijan', 'Lithuania', 'Argentina', 'Lesotho',
#        'Vietnam', 'Cuba', 'Romania', 'Turkey', 'Cameroon', 'Hungary',
#        'Singapore', 'Angola', 'Belgium', 'Pakistan', 'Finland', 'Ghana',
#        'Zambia', 'Iraq', 'Liberia', 'Georgia', 'Switzerland', 'Albania',
# ...

# %%
df['Country'].nunique()/df.shape[0]
# Out:
# 0.003217001364788458

# %%
df['Region'].nunique()
# Out:
# 23

# %%
df['Region'].unique()
# Out:
# array(['Central US', 'Oceania', 'Western Europe', 'Western Africa',
#        'Western US', 'Southern Asia', 'Western Asia', 'South America',
#        'Eastern Asia', 'Southern Europe', 'Eastern Africa',
#        'Eastern Europe', 'Northern Europe', 'Central America',
#        'Eastern US', 'Caribbean', 'Central Africa', 'Southeastern Asia',
#        'Southern US', 'North Africa', 'Southern Africa', 'Canada',
#        'Central Asia'], dtype=object)

# %%
df['Region'].nunique()/df.shape[0]
# Out:
# 0.0004484304932735426

# %%
df['Market'].nunique()
# Out:
# 5

# %%
df['Market'].unique()
# Out:
# array(['USCA', 'Asia Pacific', 'Europe', 'Africa', 'LATAM'], dtype=object)

# %%
df['Market'].nunique()/df.shape[0]
# Out:
# 9.748488984207447e-05

# %%
df['Product ID'].nunique()
# Out:
# 3788

# %%
df['Product ID'].unique()
# Out:
# array(['TEC-PH-5816', 'FUR-CH-5379', 'TEC-PH-5356', ..., 'OFF-AP-3370',
#        'TEC-MA-4598', 'TEC-PH-3808'], dtype=object)

# %%
df['Product ID'].nunique()/df.shape[0]
# Out:
# 0.07385455254435562

# %%
df['Category'].nunique()
# Out:
# 3

# %%
df['Category'].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
df['Category'].nunique()/df.shape[0]
# Out:
# 5.8490933905244686e-05

# %%
df['Sub-Category'].nunique()
# Out:
# 17

# %%
df['Sub-Category'].unique()
# Out:
# array(['Phones', 'Chairs', 'Copiers', 'Tables', 'Bookcases', 'Art',
#        'Appliances', 'Storage', 'Fasteners', 'Machines', 'Accessories',
#        'Furnishings', 'Binders', 'Labels', 'Paper', 'Supplies',
#        'Envelopes'], dtype=object)

# %%
df['Sub-Category'].nunique()/df.shape[0]
# Out:
# 0.00033144862546305323

# %%
df['Product Name'].nunique()
# Out:
# 3788

# %%
df['Product Name'].unique()
# Out:
# array(['Samsung Convoy 3', 'Novimex Executive Leather Armchair, Black',
#        'Nokia Smart Phone, with Caller ID', ...,
#        'Belkin 8 Outlet SurgeMaster II Gold Surge Protector with Phone Protection',
#        'Hewlett-Packard Deskjet D4360 Printer', 'Cisco SPA 501G IP Phone'],
#       dtype=object)

# %%
df['Product Name'].nunique()/df.shape[0]
# Out:
# 0.07385455254435562

# %%
df['Sales'].nunique()
# Out:
# 27200

# %%
df['Sales'].unique()
# Out:
# array([ 221.98 , 3709.395, 5175.171, ...,  259.96 ,   49.302,    5.364])

# %%
df['Sales'].nunique()/df.shape[0]
# Out:
# 0.5303178007408852

# %%
df['Quantity'].nunique()
# Out:
# 14

# %%
df['Quantity'].unique()
# Out:
# array([ 2,  9,  5,  8,  4,  6,  1,  3,  7, 12, 14, 10, 13, 11],
#       dtype=int64)

# %%
df['Quantity'].nunique()/df.shape[0]
# Out:
# 0.0002729576915578085

# %%
df['Quantity'].nunique()/df.shape[0]
# Out:
# 0.0002729576915578085

# %%
df['Discount'].nunique()
# Out:
# 29

# %%
df['Discount'].unique()
# Out:
# array([0.   , 0.1  , 0.2  , 0.15 , 0.17 , 0.5  , 0.47 , 0.4  , 0.7  ,
#        0.25 , 0.002, 0.07 , 0.27 , 0.3  , 0.35 , 0.15 , 0.6  , 0.65 ,
#        0.8  , 0.57 , 0.37 , 0.402, 0.55 , 0.202, 0.32 , 0.45 , 0.45 ,
#        0.602, 0.85 ])

# %%
df['Discount'].nunique()/df.shape[0]
# Out:
# 0.000565412361084032

# %%
df['Profit'].nunique()
# Out:
# 28234

# %%
df['Profit'].unique()
# Out:
# array([  62.1544, -288.765 ,  919.971 , ...,   22.0472,  -49.572 ,
#          -6.456 ])

# %%
df['Profit'].nunique()/df.shape[0]
# Out:
# 0.5504776759602261

# %%
df['Shipping Cost'].nunique()
# Out:
# 16753

# %%
df['Shipping Cost'].unique()
# Out:
# array([ 40.77 , 923.63 , 915.49 , ...,   1.019,   1.003,   1.002])

# %%
df['Shipping Cost'].nunique()/df.shape[0]
# Out:
# 0.32663287190485474

# %%
df['Order Priority'].nunique()
# Out:
# 4

# %%
df['Order Priority'].unique()
# Out:
# array(['High', 'Critical', 'Medium', 'Low'], dtype=object)

# %%
df['Order Priority'].nunique()/df.shape[0]
# Out:
# 7.798791187365959e-05

# %%
df.describe(include='all',percentiles=[0.01,0.05,0.25,0.5,0.75,0.95,0.99]).T
# Out:
# C:\Users\BHARGA~1\AppData\Local\Temp/ipykernel_15912/1869447349.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all',percentiles=[0.01,0.05,0.25,0.5,0.75,0.95,0.99]).T
#                   count unique                       top   freq      first  \
# Order ID          51290  25728  CA-2015-SV20365140-42268     14        NaT
# Order Date        51290   1430       2015-06-18 00:00:00    135 2012-01-01
# Ship Date         51290   1464       2015-11-22 00:00:00    130 2012-01-03
# Ship Mode         51290      4            Standard Class  30775        NaT
# Customer ID       51290  17415              SV-203651406     26        NaT
# Customer Name     51290    796           Muhammed Yedwab    108        NaT
# ...

# %% [markdown]
# # Univariate distributions on Numerical Variable

# %%
plt.hist(df['Sales'],edgecolor="black",bins=20)
plt.show()

# %%
plt.hist(df['Quantity'],edgecolor="black",bins=20)
plt.show()

# %%
plt.hist(df['Discount'],edgecolor="black",bins=20)
plt.show()

# %%
plt.hist(df['Profit'],edgecolor="black",bins=20)
plt.show()

# %%
plt.hist(df['Shipping Cost'],edgecolor="black",bins=20)
plt.show()

# %% [markdown]
# # Univariate Distributions On Object Variable

# %%
plt.figure(figsize=(100,20))
plt.bar(df['Market'],df['Discount'],edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(100,20))
plt.bar(df['City'],df['Shipping Cost'],edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(100,20))
plt.bar(df['Country'],df['Profit'],edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(200,40))
plt.bar(df['Country'],df['Quantity'],edgecolor='blue')
plt.show()

# %% [markdown]
# # Bi-Variate Distributions

# %% [markdown]
# # Cross Tab

# %%
pd.crosstab(df['Product Name'],df['Order Priority'])
# Out:
# Order Priority                                      Critical  High  Low  \
# Product Name
# "While you Were Out" Message Book, One Form per...         0     1    0
# #10 Gummed Flap White Envelopes, 100/Box                   0     0    0
# #10 Self-Seal White Envelopes                              1     0    0
# #10 White Business Envelopes,4 1/8 x 9 1/2                 0     3    0
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                    1     2    1
# ...                                                      ...   ...  ...
# iKross Bluetooth Portable Keyboard + Cell Phone...         0     0    0
# iOttie HLCRIO102 Car Mount                                 1     0    0
# iOttie XL Car Mount                                        0     1    0
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...         0     0    1
# netTALK DUO VoIP Telephone Service                         0     2    0
#
# Order Priority                                      Medium
# Product Name
# ...

# %%
plt.figure(figsize=(100,40))
sns.countplot(data=df,x='Sub-Category',hue='Order Priority')
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %% [markdown]
# # SCATTER PLOT

# %%
plt.scatter(data=df,y='Profit',x='Quantity')
plt.title('ProfitvsQuantity')
plt.figure(figsize=(15,5))

# %% [markdown]
# # PHASE -02

# %%
df=pd.read_excel('office supplies.xlsx',sheet_name='Data')
df

# %%
df['Product ID'].nunique()
# Out:
# 3788

# %%
df.nunique()
# Out:
# Order ID          25728
# Order Date         1430
# Ship Date          1464
# Ship Mode             4
# Customer ID       17415
# Customer Name       796
# Segment               3
# Postal Code         631
# City               3650
# State              1102
# Country             165
# Region               23
# Market                5
# Product ID         3788
# Category              3
# Sub-Category         17
# Product Name       3788
# Sales             27200
# Quantity             14
# Discount             29
# Profit            28234
# Shipping Cost     16753
# Order Priority        4
# dtype: int64

# %%
a=df["Customer ID"].nunique()
a
# Out:
# 17415

# %%
df["Order ID"].nunique()
# Out:
# 25728

# %%
df["Product ID"].nunique()
# Out:
# 3788

# %%
plt.hist(df['Product ID'])
plt.show()

# %%
plt.bar(['Customer ID','Order ID','Product ID'],[17415,25728,3788])
plt.show()

# %%
df.describe(include ='object')
# Out:
#                         Order ID       Ship Mode   Customer ID  \
# count                      51290           51290         51290
# unique                     25728               4         17415
# top     CA-2015-SV20365140-42268  Standard Class  SV-203651406
# freq                          14           30775            26
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              796         3           3650        1102            165
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#                 Region        Market   Product ID         Category  \
# count            51290         51290        51290            51290
# unique              23             5         3788                3
# ...

# %%
df
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1        IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2        IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                         ...        ...        ...             ...
# 51285   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %% [markdown]
# # question 3

# %%
(df['Customer ID'].value_counts()>5).sum()
# Out:
# 2247

# %%
plt.bar(['Order1','Order2','Order3','Order4','Order5'],[6065,3760,2552,1659,1132])
plt.show()

# %%
k = df['Customer ID'].value_counts()
k.value_counts()
# Out:
# 1     6065
# 2     3760
# 3     2552
# 4     1659
# 5     1132
# 6      788
# 7      488
# 8      310
# 9      232
# 10     169
# 11      87
# 12      61
# 13      40
# 14      22
# 15      22
# 16       9
# 17       8
# 18       4
# 19       2
# 24       1
# 20       1
# 21       1
# 23       1
# 26       1
# Name: Customer ID, dtype: int64

# %%
df['Customer ID'].count()
# Out:
# 51290

# %%
a = df['Customer ID'].count()
a
# Out:
# 51290

# %%
order_count = df[df.duplicated('Customer ID')]

# %%
order_count.value_counts()
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # question 2

# %%
single = a/df.shape[0]*100
single
# Out:
# 33.95398713199454

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
repeat = b/df.shape[0]*100
repeat
# Out:
# 66.04601286800545

# %%
plt.bar(['single','repeat'],[33,67])
plt.show()

# %%
is_dup = df[df.duplicated('Customer ID')]

# %%
is_dup['Customer ID'].value_counts()
# Out:
# SV-203651406    25
# WB-218501404    23
# AP-109151404    22
# EM-1396082      20
# CS-121757       19
#                 ..
# SJ-2050058       1
# DC-32853         1
# DK-13225139      1
# GM-1444045       1
# JK-15370120      1
# Name: Customer ID, Length: 11350, dtype: int64

# %%
df.drop_duplicates(subset='Customer ID')
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1        IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2        IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                         ...        ...        ...             ...
# 51261  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51262  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51265  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  Standard Class
# 51275    ZA-2012-AS285147-40988 2012-03-20 2012-03-25  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
df['Product Name'].value_counts(3)
# Out:
# Staples                                                 0.004426
# Cardinal Index Tab, Clear                               0.001794
# Eldon File Cart, Single Width                           0.001755
# Rogers File Cart, Single Width                          0.001638
# Ibico Index Tab, Clear                                  0.001618
#                                                           ...
# Lexmark X 9575 Professional All-in-One Color Printer    0.000019
# NETGEAR RangeMax WNR1000 Wireless Router                0.000019
# 4009 Highlighters                                       0.000019
# Xerox 1938                                              0.000019
# Cisco SPA 501G IP Phone                                 0.000019
# Name: Product Name, Length: 3788, dtype: float64

# %% [markdown]
# # question 4

# %%
totalsales = df.groupby('Sub-Category')['Sales'].mean()
totalsales
# Out:
# Sub-Category
# Accessories    243.654315
# Appliances     580.100761
# Art             76.400731
# Binders         75.149592
# Bookcases      608.283800
# Chairs         437.298126
# Copiers        679.008670
# Envelopes       70.891282
# Fasteners       34.407938
# Furnishings    122.116667
# Labels          28.200798
# Machines       524.266532
# Paper           69.240414
# Phones         508.437337
# Storage        223.175474
# Supplies       100.877080
# Tables         879.258913
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(18,7))
sns.countplot(data=df,x='Sub-Category')
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='count'>

# %%
plt.figure(figsize=(18,7))
sns.barplot(data=df,x='Sub-Category',y='Sales',ci=None)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Sales'>

# %%
totalsales = df.groupby('Sub-Category')['Quantity'].mean()
totalsales
# Out:
# Sub-Category
# Accessories    3.559675
# Appliances     3.459242
# Art            3.333676
# Binders        3.482428
# Bookcases      3.446703
# Chairs         3.592312
# Copiers        3.353126
# Envelopes      3.439464
# Fasteners      3.479815
# Furnishings    3.539315
# Labels         3.575932
# Machines       3.301480
# Paper          3.628866
# Phones         3.535895
# Storage        3.344029
# Supplies       3.523889
# Tables         3.580720
# Name: Quantity, dtype: float64

# %%
plt.figure(figsize=(18,7))
sns.barplot(data=df,x='Sub-Category',y='Quantity',ci =None)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Quantity'>

# %%
df.groupby('Sub-Category')['Discount'].mean()
# Out:
# Sub-Category
# Accessories    0.120481
# Appliances     0.142078
# Art            0.117574
# Binders        0.179284
# Bookcases      0.153758
# Chairs         0.163110
# Copiers        0.117147
# Envelopes      0.132891
# Fasteners      0.137193
# Furnishings    0.150628
# Labels         0.120527
# Machines       0.169583
# Paper          0.110109
# Phones         0.145847
# Storage        0.138540
# Supplies       0.128043
# Tables         0.290732
# Name: Discount, dtype: float64

# %%
plt.figure(figsize=(18,7))
sns.barplot(data=df,x='Sub-Category',y='Discount',ci=None)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Discount'>

# %%
df['Discount'].mean()
# Out:
# 0.1429075453304631

# %%
df.groupby('Sub-Category')['Profit'].mean()
# Out:
# Sub-Category
# Accessories     42.154896
# Appliances      81.264402
# Art             11.889363
# Binders         11.785414
# Bookcases       67.160688
# Chairs          40.884178
# Copiers        116.314687
# Envelopes       12.086086
# Fasteners        5.322679
# Furnishings     14.852705
# Labels           5.762754
# Machines        39.614989
# Paper           16.641367
# Phones          64.556749
# Storage         21.472902
# Supplies         9.372329
# Tables         -74.429023
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(18,7))
sns.barplot(data=df,x='Sub-Category',y='Profit',ci=None)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Profit'>

# %%
df.groupby('Sub-Category')['Shipping Cost'].mean()
# Out:
# Sub-Category
# Accessories    27.184499
# Appliances     62.174366
# Art             8.612065
# Binders         8.098455
# Bookcases      64.491069
# Chairs         47.831494
# Copiers        71.750430
# Envelopes       7.785072
# Fasteners       3.960042
# Furnishings    12.993550
# Labels          3.398972
# Machines       53.263693
# Paper           7.693037
# Phones         55.094874
# Storage        23.924312
# Supplies       10.365944
# Tables         92.756555
# Name: Shipping Cost, dtype: float64

# %%
plt.figure(figsize=(18,7))
sns.barplot(data=df,x='Sub-Category',y='Shipping Cost',ci =None)
# Out:
# <AxesSubplot:xlabel='Sub-Category', ylabel='Shipping Cost'>

# %% [markdown]
# # QUESTION 5

# %%
df
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1        IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2        IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                         ...        ...        ...             ...
# 51285   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
df.describe(include ='object')
# Out:
#                         Order ID       Ship Mode   Customer ID  \
# count                      51290           51290         51290
# unique                     25728               4         17415
# top     CA-2015-SV20365140-42268  Standard Class  SV-203651406
# freq                          14           30775            26
#
#           Customer Name   Segment           City       State        Country  \
# count             51290     51290          51290       51290          51290
# unique              796         3           3650        1102            165
# top     Muhammed Yedwab  Consumer  New York City  California  United States
# freq                108     26518            915        2001           9994
#
#                 Region        Market   Product ID         Category  \
# count            51290         51290        51290            51290
# unique              23             5         3788                3
# ...

# %%
df['Market'].value_counts()
# Out:
# Asia Pacific    14302
# Europe          11729
# USCA            10378
# LATAM           10294
# Africa           4587
# Name: Market, dtype: int64

# %%
df['Product Name'].value_counts()
# Out:
# Staples                                                 227
# Cardinal Index Tab, Clear                                92
# Eldon File Cart, Single Width                            90
# Rogers File Cart, Single Width                           84
# Ibico Index Tab, Clear                                   83
#                                                        ...
# Lexmark X 9575 Professional All-in-One Color Printer      1
# NETGEAR RangeMax WNR1000 Wireless Router                  1
# 4009 Highlighters                                         1
# Xerox 1938                                                1
# Cisco SPA 501G IP Phone                                   1
# Name: Product Name, Length: 3788, dtype: int64

# %%
product_sales.nlargest(3,['Sales'])
# Out:
#                      Order ID Order Date  Ship Date       Ship Mode  \
# 81     MO-2015-DP310586-42305 2015-10-28 2015-10-30    Second Class
# 3675   IV-2012-NW840029-41130 2012-08-09 2012-08-13  Standard Class
# 291   SG-2015-JW5220111-42108 2015-04-14 2015-04-17    Second Class
#
#      Customer ID   Customer Name    Segment  Postal Code     City  \
# 81     DP-310586    Dave Poirier  Corporate          NaN   Meknes
# 3675   NW-840029  Natalie Webber   Consumer          NaN  Abidjan
# 291   JW-5220111       Jane Waco  Corporate          NaN    Dakar
#
#                  State  ...   Product ID    Category Sub-Category  \
# 81    Meknès-Tafilalet  ...  TEC-CO-3710  Technology      Copiers
# 3675           Lagunes  ...  TEC-PH-3148  Technology       Phones
# 291              Dakar  ...  TEC-PH-3805  Technology       Phones
#
#                       Product Name    Sales Quantity Discount   Profit  \
# 81       Canon Wireless Fax, Laser  5301.24       14      0.0  2597.28
# ...

# %%
df.groupby('Market')['Profit'].sum()
# Out:
# Market
# Africa           88871.63100
# Asia Pacific    403176.03800
# Europe          449551.72350
# LATAM           221643.48708
# USCA            304214.41170
# Name: Profit, dtype: float64

# %%
df['Product Name'].nunique()
# Out:
# 3788

# %%
product_sales = df[df['Market']=='Africa']

# %%
product_sales
# Out:
#                       Order ID Order Date  Ship Date       Ship Mode  \
# 4      SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# 19     TZ-2015-RH9555129-42343 2015-12-05 2015-12-07    Second Class
# 35     CG-2012-AH1003033-41165 2012-09-13 2012-09-14     First Class
# 54      MZ-2014-DG330087-41991 2014-12-18 2014-12-18        Same Day
# 72      CG-2014-BW106533-41727 2014-03-29 2014-03-31    Second Class
# ...                        ...        ...        ...             ...
# 51233    NI-2013-AA64595-41434 2013-06-09 2013-06-09        Same Day
# 51240   NI-2015-JR570095-42356 2015-12-18 2015-12-23  Standard Class
# 51247   EG-2014-PM894038-41846 2014-07-26 2014-07-30  Standard Class
# 51275   ZA-2012-AS285147-40988 2012-03-20 2012-03-25  Standard Class
# 51279   NI-2012-PO886595-41159 2012-09-07 2012-09-09    Second Class
#
#       Customer ID      Customer Name    Segment  Postal Code        City  \
# ...

# %%
market2 = df[df['Market']=='Asia Pacific']
market2
# Out:
#                       Order ID Order Date  Ship Date       Ship Mode  \
# 1       IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2       IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 5       IN-2014-JM156557-41818 2014-06-28 2014-07-01    Second Class
# 6      IN-2012-TS2134092-41219 2012-11-06 2012-11-08     First Class
# 7      IN-2013-MB1808592-41378 2013-04-14 2013-04-18  Standard Class
# ...                        ...        ...        ...             ...
# 51268  SA-2015-JW6075110-42103 2015-04-09 2015-04-13  Standard Class
# 51277  TU-2015-KF6285134-42337 2015-11-29 2015-11-30     First Class
# 51282   IN-2015-DB132707-42221 2015-08-05 2015-08-10  Standard Class
# 51283  IN-2015-KH1633058-42154 2015-05-30 2015-05-30        Same Day
# 51285  IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
#
#       Customer ID      Customer Name      Segment  Postal Code        City  \
# ...

# %%
market2.nlargest(3,['Sales'])
# Out:
#                      Order ID Order Date  Ship Date       Ship Mode  \
# 215   ID-2012-CA1196566-40949 2012-02-10 2012-02-15  Standard Class
# 641   IN-2014-AS1063092-41989 2014-12-16 2014-12-20  Standard Class
# 1156   ID-2013-SC203057-41488 2013-08-02 2013-08-08  Standard Class
#
#      Customer ID     Customer Name      Segment  Postal Code       City  \
# 215   CA-1196566       Carol Adams    Corporate          NaN       Fuji
# 641   AS-1063092        Ann Steele  Home Office          NaN  Whakatane
# 1156   SC-203057  Sean Christensen     Consumer          NaN   Adelaide
#
#                 State  ...   Product ID    Category Sub-Category  \
# 215          Shizuoka  ...  TEC-PH-5841  Technology       Phones
# 641     Bay of Plenty  ...  TEC-PH-5268  Technology       Phones
# 1156  South Australia  ...  FUR-CH-4655   Furniture       Chairs
#
#                                Product Name     Sales Quantity Discount  \
# ...

# %%
market3 = df[df['Market']=='Europe']
market3
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 15      ES-2015-BP1118545-42216 2015-07-31 2015-08-03    Second Class
# 17      ES-2015-PJ1883564-42255 2015-09-08 2015-09-14  Standard Class
# 20       PL-2013-AB600103-41494 2013-08-08 2013-08-10     First Class
# 23     ES-2014-LB16795139-41697 2014-02-27 2014-03-01    Second Class
# ...                         ...        ...        ...             ...
# 51254   RS-2015-DP3000108-42355 2015-12-17 2015-12-20    Second Class
# 51258  ES-2015-MM17920139-42147 2015-05-23 2015-05-25     First Class
# 51269  ES-2012-MM18055139-41038 2012-05-09 2012-05-13  Standard Class
# 51270   ES-2015-NM1852045-42221 2015-08-05 2015-08-11  Standard Class
# 51278   ES-2012-LR1703548-41245 2012-12-02 2012-12-02        Same Day
#
#        Customer ID     Customer Name      Segment  Postal Code  \
# ...

# %%
market3.nlargest(3,['Sales'])
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 17      ES-2015-PJ1883564-42255 2015-09-08 2015-09-14  Standard Class
# 11246  ES-2012-ER13855120-41159 2012-09-07 2012-09-10    Second Class
# 43     ES-2013-GT14710139-41621 2013-12-13 2013-12-17  Standard Class
#
#        Customer ID      Customer Name    Segment  Postal Code          City  \
# 17      PJ-1883564      Patrick Jones  Corporate          NaN         Prato
# 11246  ER-13855120  Elpida Rittenbach  Corporate          NaN          Lugo
# 43     GT-14710139          Greg Tran   Consumer          NaN  Huddersfield
#
#          State  ...   Product ID         Category Sub-Category  \
# 17     Tuscany  ...  OFF-AP-4743  Office Supplies   Appliances
# 11246  Galicia  ...  OFF-AP-4507  Office Supplies   Appliances
# 43     England  ...  TEC-PH-5267       Technology       Phones
#
#                          Product Name    Sales Quantity Discount   Profit  \
# ...

# %%
market4 = df[df['Market']=='LATAM']
market4
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 13      MX-2013-VF2171518-41591 2013-11-13 2013-11-13        Same Day
# 24      US-2015-NP1832582-42216 2015-07-31 2015-08-01     First Class
# 25      MX-2015-VD2167039-42252 2015-09-05 2015-09-08     First Class
# 30      US-2012-RR1952536-41270 2012-12-27 2012-12-29    Second Class
# 49     MX-2015-JH15820141-42356 2015-12-18 2015-12-20    Second Class
# ...                         ...        ...        ...             ...
# 51274   MX-2014-SS2041082-41912 2014-09-30 2014-10-02    Second Class
# 51281   MX-2015-HG1502518-42164 2015-06-09 2015-06-11     First Class
# 51284   MX-2013-KM1637593-41636 2013-12-28 2013-12-31     First Class
# 51288   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#        Customer ID      Customer Name      Segment  Postal Code  \
# ...

# %%
market4.nlargest(3,['Sales'])
# Out:
#                       Order ID Order Date  Ship Date       Ship Mode  \
# 284    MX-2013-FH1436582-41628 2013-12-20 2013-12-24  Standard Class
# 49    MX-2015-JH15820141-42356 2015-12-18 2015-12-20    Second Class
# 2382   MX-2015-AC1042082-42348 2015-12-10 2015-12-15  Standard Class
#
#       Customer ID  Customer Name    Segment  Postal Code         City  \
# 284    FH-1436582   Fred Hopkins  Corporate          NaN  Mexico City
# 49    JH-15820141    John Huston   Consumer          NaN     Paysandú
# 2382   AC-1042082  Alyssa Crouse  Corporate          NaN      Apodaca
#
#                  State  ...   Product ID    Category Sub-Category  \
# 284   Distrito Federal  ...  TEC-PH-3806  Technology       Phones
# 49            Paysandú  ...  FUR-CH-4531   Furniture       Chairs
# 2382        Nuevo León  ...  FUR-CH-5775   Furniture       Chairs
#
#                                            Product Name     Sales Quantity  \
# ...

# %%
market5 = df[df['Market']=='USCA']
market5
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 8      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 9      CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 10     CA-2012-AB10015140-40974 2012-03-06 2012-03-07     First Class
# 16     CA-2012-AB10015140-40958 2012-02-19 2012-02-25  Standard Class
# ...                         ...        ...        ...             ...
# 51271  CA-2014-ZD21925140-41733 2014-04-04 2014-04-10  Standard Class
# 51276  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51280  CA-2014-ZD21925140-41829 2014-07-09 2014-07-09        Same Day
# 51286  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
#
#         Customer ID       Customer Name   Segment  Postal Code           City  \
# ...

# %%
market5.nlargest(5,['Sales'])
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 47114  CA-2012-SM20320140-40985 2012-03-17 2012-03-22  Standard Class
# 49003  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
# 44248  CA-2015-RB19360140-42087 2015-03-24 2015-03-26     First Class
# 49940  CA-2015-TA21385140-42300 2015-10-23 2015-10-25     First Class
# 25238  CA-2015-HL15040140-42326 2015-11-18 2015-11-23  Standard Class
#
#         Customer ID Customer Name      Segment  Postal Code           City  \
# 47114  SM-203201408   Sean Miller  Home Office      32216.0   Jacksonville
# 49003  TC-209801402  Tamara Chand    Corporate      47905.0      Lafayette
# 44248  RB-193601404  Raymond Buch     Consumer      98115.0        Seattle
# 49940  TA-213851406  Tom Ashbrook  Home Office      10024.0  New York City
# 25238  HL-150401406  Hunter Lopez     Consumer      19711.0         Newark
#
#             State  ...   Product ID    Category Sub-Category  \
# ...

# %% [markdown]
# # question 6

# %%
days = df['Ship Date'].dt.date-df['Order Date'].dt.date
days
# Out:
# 0       2 days
# 1       2 days
# 2       1 days
# 3       2 days
# 4       1 days
#          ...
# 51285   0 days
# 51286   4 days
# 51287   5 days
# 51288   4 days
# 51289   4 days
# Length: 51290, dtype: timedelta64[ns]

# %%
days.value_counts(normalize = True).round(2)
# Out:
# 4 days    0.28
# 5 days    0.22
# 2 days    0.14
# 6 days    0.12
# 3 days    0.10
# 7 days    0.06
# 0 days    0.05
# 1 days    0.03
# dtype: float64

# %%
plt.bar(['Day0','Days1','Days2','Days3','Days4','Days5','Days6','Days7'],[0.05,0.03,0.05,0.13,0.09,0.28,0.21,0.12])
plt.show()

# %% [markdown]
# # question 7

# %%
plt.scatter(data=df,y='Sales',x='Quantity')
plt.show()

# %%
plt.scatter(data=df,y='Sales',x='Discount')
plt.show()

# %%
plt.scatter(data=df,y='Sales',x='Profit')
plt.show()

# %% [markdown]
# # question 8

# %%
df.groupby('Order ID').agg({'Sales':['mean','median']})
# Out:
#                             Sales
#                              mean   median
# Order ID
# AE-2012-PO8865138-41184    80.541   80.541
# AE-2014-EB4110138-41926   114.498  114.498
# AE-2014-MY7380138-42004    11.817   11.817
# AE-2015-GH4665138-42351    46.917   50.931
# AE-2015-JD5790138-42070     6.426    6.426
# ...                           ...      ...
# ZA-2015-RC9960146-42257    16.680   16.680
# ZA-2015-RP9390146-42099    90.360   90.360
# ZA-2015-SM10005146-42241   63.030   63.030
# ZA-2015-SW10350146-42061  253.905  253.905
# ZA-2015-TS11205146-42062  292.170  292.170
#
# [25728 rows x 2 columns]

# %%
df.groupby('Ship Mode').agg({'Sales':['mean','median']})
# Out:
#                      Sales
#                       mean median
# Ship Mode
# First Class     243.967507  84.42
# Same Day        247.020357  83.55
# Second Class    248.876873  84.50
# Standard Class  246.260020  85.68

# %%
df.groupby('Customer ID').agg({'Sales':['mean','median']})
# Out:
#                     Sales
#                      mean      median
# Customer ID
# AA-10315102     90.776000    48.32025
# AA-10315120   2713.410000  2713.41000
# AA-10315139    227.369077   159.48000
# AA-103151402   796.758667   202.33000
# AA-103151404   251.169333    52.98000
# ...                   ...         ...
# ZD-2192548     325.542000    70.38000
# ZD-2192564     306.348000    96.64200
# ZD-219257       59.940000    59.94000
# ZD-2192582     339.050700   339.05070
# ZD-2192596     134.655000   134.65500
#
# [17415 rows x 2 columns]

# %% [markdown]
# # section5

# %%
df
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1        IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2        IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                         ...        ...        ...             ...
# 51285   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
df['Customer ID'].value_counts()
# Out:
# SV-203651406    26
# WB-218501404    24
# AP-109151404    23
# EM-1396082      21
# CS-121757       20
#                 ..
# LW-7215110       1
# XP-2186531       1
# FP-14320139      1
# JK-16090101      1
# MC-1810093       1
# Name: Customer ID, Length: 17415, dtype: int64

# %%
df['Order ID'].nunique()
# Out:
# 25728

# %%
pd.crosstab(df['Customer ID'],df[''])
# Out:
# Order ID      AE-2012-PO8865138-41184  AE-2014-EB4110138-41926  \
# Customer ID
# AA-10315102                         0                        0
# AA-10315120                         0                        0
# AA-10315139                         0                        0
# AA-103151402                        0                        0
# AA-103151404                        0                        0
# ...                               ...                      ...
# ZD-2192548                          0                        0
# ZD-2192564                          0                        0
# ZD-219257                           0                        0
# ZD-2192582                          0                        0
# ZD-2192596                          0                        0
#
# Order ID      AE-2014-MY7380138-42004  AE-2015-GH4665138-42351  \
# Customer ID
# AA-10315102                         0                        0
# ...

# %%
df['Sales']-df['Profit']
# Out:
# 0         159.8256
# 1        3998.1600
# 2        4255.2000
# 3        2989.0500
# 4        2521.4400
#            ...
# 51285      60.6000
# 51286      13.3760
# 51287       6.0776
# 51288      11.0400
# 51289      59.5800
# Length: 51290, dtype: float64

# %%
large = df['Product Name']
large
# Out:
# 0                                     Samsung Convoy 3
# 1            Novimex Executive Leather Armchair, Black
# 2                    Nokia Smart Phone, with Caller ID
# 3                       Motorola Smart Phone, Cordless
# 4                       Sharp Wireless Fax, High-Speed
#                              ...
# 51285                    Advantus Thumb Tacks, 12 Pack
# 51286    Eldon Image Series Desk Accessories, Burgundy
# 51287                                       Newell 341
# 51288                          Acco Index Tab, Economy
# 51289          Eaton Computer Printout Paper, 8.5 x 11
# Name: Product Name, Length: 51290, dtype: object

# %%
large.nlargest(all,['Profit'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\BHARGA~1\AppData\Local\Temp/ipykernel_11212/1930719962.py in <module>
# ----> 1 large.nlargest(all,['Profit'])
#
# C:\anaconda\lib\site-packages\pandas\core\series.py in nlargest(self, n, keep)
#    3765         dtype: int64
#    3766         """
# -> 3767         return algorithms.SelectNSeries(self, n=n, keep=keep).nlargest()
#    3768
#    3769     def nsmallest(self, n: int = 5, keep: str = "first") -> Series:
#
# C:\anaconda\lib\site-packages\pandas\core\algorithms.py in __init__(self, obj, n, keep)
#    1212
#    1213         if self.keep not in ("first", "last", "all"):
# -> 1214             raise ValueError('keep must be either "first", "last" or "all"')
#    1215
#    1216     def compute(self, method: str) -> FrameOrSeriesUnion:
#
# ValueError: keep must be either "first", "last" or "all"

# %%
df.nlargest(1,['Profit'],keep='all')
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 49003  CA-2014-TC20980140-41915 2014-10-03 2014-10-10  Standard Class
#
#         Customer ID Customer Name    Segment  Postal Code       City    State  \
# 49003  TC-209801402  Tamara Chand  Corporate      47905.0  Lafayette  Indiana
#
#        ...   Product ID    Category Sub-Category  \
# 49003  ...  TEC-CO-3691  Technology      Copiers
#
#                                 Product Name     Sales Quantity Discount  \
# 49003  Canon imageCLASS 2200 Advanced Copier  17499.95        5      0.0
#
#          Profit  Shipping Cost  Order Priority
# 49003  8399.976         349.07          Medium
#
# [1 rows x 23 columns]

# %%
market5.nlargest(5,['Sales'])

# %%
market4 = df[df['Market']=='LATAM']
market4

# %%
df.nsmallest(3,['Profit'],keep='all')
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 11755  CA-2014-CS12505140-41969 2014-11-26 2014-12-03  Standard Class
# 6591    TU-2014-DM3345134-41908 2014-09-26 2014-09-26        Same Day
# 23110  US-2015-GT14635140-42313 2015-11-05 2015-11-05        Same Day
#
#         Customer ID   Customer Name    Segment  Postal Code        City  \
# 11755  CS-125051406   Cindy Stewart   Consumer      43130.0   Lancaster
# 6591     DM-3345134   Denise Monton  Corporate          NaN     Bornova
# 23110  GT-146351408  Grant Thornton  Corporate      27217.0  Burlington
#
#                 State  ...   Product ID    Category Sub-Category  \
# 11755            Ohio  ...  TEC-MA-3854  Technology     Machines
# 6591            Izmir  ...  TEC-PH-5267  Technology       Phones
# 23110  North Carolina  ...  TEC-MA-3855  Technology     Machines
#
#                                     Product Name     Sales Quantity Discount  \
# ...

# %%
k = df['Product Name']
k
# Out:
# 0                                     Samsung Convoy 3
# 1            Novimex Executive Leather Armchair, Black
# 2                    Nokia Smart Phone, with Caller ID
# 3                       Motorola Smart Phone, Cordless
# 4                       Sharp Wireless Fax, High-Speed
#                              ...
# 51285                    Advantus Thumb Tacks, 12 Pack
# 51286    Eldon Image Series Desk Accessories, Burgundy
# 51287                                       Newell 341
# 51288                          Acco Index Tab, Economy
# 51289          Eaton Computer Printout Paper, 8.5 x 11
# Name: Product Name, Length: 51290, dtype: object

# %%
df
# Out:
#                        Order ID Order Date  Ship Date       Ship Mode  \
# 0      CA-2014-AB10015140-41954 2014-11-11 2014-11-13     First Class
# 1        IN-2014-JR162107-41675 2014-02-05 2014-02-07    Second Class
# 2        IN-2014-CR127307-41929 2014-10-17 2014-10-18     First Class
# 3       ES-2014-KM1637548-41667 2014-01-28 2014-01-30     First Class
# 4       SG-2014-RH9495111-41948 2014-11-05 2014-11-06        Same Day
# ...                         ...        ...        ...             ...
# 51285   IN-2015-KE1642066-42174 2015-06-19 2015-06-19        Same Day
# 51286  US-2014-ZD21925140-41765 2014-05-06 2014-05-10  Standard Class
# 51287  CA-2012-ZD21925140-41147 2012-08-26 2012-08-31    Second Class
# 51288   MX-2013-RB1979518-41322 2013-02-17 2013-02-21  Standard Class
# 51289   MX-2013-MC1810093-41416 2013-05-22 2013-05-26    Second Class
#
#         Customer ID       Customer Name      Segment  Postal Code  \
# ...

# %%
df.groupby('Product Name').agg({'Discount':['mean','median']})
# Out:
#                                                     Discount
#                                                         mean median
# Product Name
# "While you Were Out" Message Book, One Form per...  0.133333    0.2
# #10 Gummed Flap White Envelopes, 100/Box            0.100000    0.1
# #10 Self-Seal White Envelopes                       0.050000    0.0
# #10 White Business Envelopes,4 1/8 x 9 1/2          0.057143    0.0
# #10- 4 1/8" x 9 1/2" Recycled Envelopes             0.080000    0.0
# ...                                                      ...    ...
# iKross Bluetooth Portable Keyboard + Cell Phone...  0.080000    0.0
# iOttie HLCRIO102 Car Mount                          0.160000    0.2
# iOttie XL Car Mount                                 0.200000    0.2
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...  0.171429    0.2
# netTALK DUO VoIP Telephone Service                  0.171429    0.2
#
# [3788 rows x 2 columns]

# %%
plt.figure(figsize=(18,7))
sns.barplot(data=df,x='Product Name',y='Profit',ci=None)
# Out:
# <AxesSubplot:xlabel='Product Name', ylabel='Profit'>

# %%
l = pd.crosstab(df['Product Name'],df['Profit']).mean()
l
# Out:
# Profit
# -6599.9780    0.000264
# -4088.3760    0.000264
# -3839.9904    0.000264
# -3701.8928    0.000264
# -3399.9800    0.000264
#                 ...
#  4630.4755    0.000264
#  4946.3700    0.000264
#  5039.9856    0.000264
#  6719.9808    0.000264
#  8399.9760    0.000264
# Length: 28234, dtype: float64

# %%
df['Segment'].value_counts(normalize = True)
# Out:
# Consumer       0.517021
# Corporate      0.300819
# Home Office    0.182160
# Name: Segment, dtype: float64
